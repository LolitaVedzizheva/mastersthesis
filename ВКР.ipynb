# %% [markdown]
# # Импорт данных, разведочный анализ данных
#
# ## Импорт данных

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn 
# %matplotlib inline

# %%
db=pd.read_csv("Опрос.csv", sep=';')

# %% [markdown]
# ## Разведочный анализ данных

# %%
db_copy=db.copy()
db_copy.head()
# Out:
#        Sex    Age       Region                 Fstat   Children            Ed  \
# 0  Мужской  18–24  Москва и МО  Не женат/ не замужем  Нет детей   Бакалавриат
# 1  Женский  18–24  Москва и МО  Не женат/ не замужем  Нет детей  Магистратура
# 2  Женский  18–24  Москва и МО  Не женат/ не замужем  Нет детей  Магистратура
# 3  Женский  18–24  Москва и МО  Не женат/ не замужем  Нет детей   Бакалавриат
# 4  Женский  18–24  Москва и МО  Не женат/ не замужем  1 ребенок   Бакалавриат
#
#                                              Emp                   Years  \
# 0          Работаю в компании (полная занятость)               До 1 года
# 1          Работаю в компании (полная занятость)  От 3-х лет до 5-ти лет
# 2          Работаю в компании (полная занятость)               До 1 года
# 3          Работаю в компании (полная занятость)  От 3-х лет до 5-ти лет
# 4  Совмещаю работу в офисе и собственные проекты  От 3-х лет до 5-ти лет
#
#                       Group  \
# ...

# %%
print ("The shape of the  data is (row, column):"+ str(db.shape))
print (db_copy.info())
# Out:
# The shape of the  data is (row, column):(180, 26)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 26 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sex          180 non-null    object
#  1   Age          180 non-null    object
#  2   Region       180 non-null    object
#  3   Fstat        180 non-null    object
#  4   Children     180 non-null    object
#  5   Ed           180 non-null    object
#  6   Emp          180 non-null    object
#  7   Years        180 non-null    object
#  8   Group        180 non-null    object
#  9   Comp         180 non-null    object
#  10  Market       180 non-null    object
#  11  Sphere       180 non-null    object
#  12  Interview    180 non-null    object
#  13  DigitalTech  180 non-null    object
#  14  Vid          180 non-null    object
#  15  Chat         180 non-null    object
#  16  Lk           180 non-null    object
# ...

# %%
db_copy.dtypes
# Out:
# Sex            object
# Age            object
# Region         object
# Fstat          object
# Children       object
# Ed             object
# Emp            object
# Years          object
# Group          object
# Comp           object
# Market         object
# Sphere         object
# Interview      object
# DigitalTech    object
# Vid            object
# Chat           object
# Lk             object
# Social1         int64
# Social2        object
# Social3        object
# AI             object
# VR             object
# AdvVR          object
# AdvDig         object
# DisadvDig      object
# Level           int64
# dtype: object

# %% [markdown]
# ## Очистка данных

# %%
print('Data columns with null values:',db.isnull().sum(), sep = '\n')
# Out:
# Data columns with null values:
# Sex            0
# Age            0
# Region         0
# Fstat          0
# Children       0
# Ed             0
# Emp            0
# Years          0
# Group          0
# Comp           0
# Market         0
# Sphere         0
# Interview      0
# DigitalTech    0
# Vid            0
# Chat           0
# Lk             0
# Social1        0
# Social2        0
# Social3        0
# AI             0
# VR             0
# AdvVR          0
# AdvDig         0
# DisadvDig      0
# Level          0
# dtype: int64

# %%
sns.heatmap(db.isna(),cbar=False)
plt.show()

# %%
print('Data columns with null values:',db_copy.isnull().sum(), sep = '\n')
# Out:
# Data columns with null values:
# Sex            0
# Age            0
# Region         0
# Fstat          0
# Children       0
# Ed             0
# Emp            0
# Years          0
# Group          0
# Comp           0
# Market         0
# Sphere         0
# Interview      0
# DigitalTech    0
# Vid            0
# Chat           0
# Lk             0
# Social1        0
# Social2        0
# Social3        0
# AI             0
# VR             0
# AdvVR          0
# AdvDig         0
# DisadvDig      0
# Level          0
# dtype: int64

# %%
db_copy.head()
# Out:
#        Sex    Age       Region                 Fstat   Children            Ed  \
# 0  Мужской  18–24  Москва и МО  Не женат/ не замужем  Нет детей   Бакалавриат
# 1  Женский  18–24  Москва и МО  Не женат/ не замужем  Нет детей  Магистратура
# 2  Женский  18–24  Москва и МО  Не женат/ не замужем  Нет детей  Магистратура
# 3  Женский  18–24  Москва и МО  Не женат/ не замужем  Нет детей   Бакалавриат
# 4  Женский  18–24  Москва и МО  Не женат/ не замужем  1 ребенок   Бакалавриат
#
#                                              Emp                   Years  \
# 0          Работаю в компании (полная занятость)               До 1 года
# 1          Работаю в компании (полная занятость)  От 3-х лет до 5-ти лет
# 2          Работаю в компании (полная занятость)               До 1 года
# 3          Работаю в компании (полная занятость)  От 3-х лет до 5-ти лет
# 4  Совмещаю работу в офисе и собственные проекты  От 3-х лет до 5-ти лет
#
#                       Group  \
# ...

# %% [markdown]
# ## Визуализация данных
# ### Построение графиков для определение категориальных признаков

# %%
plt.figure(figsize = (15, 7))
plt.style.use('seaborn-white')

#Пол
plt.subplot(234)
ax=sns.countplot(x="Sex", data=db, facecolor=(0, 0, 0, 0),
                 linewidth=5,edgecolor=sns.color_palette("magma", 3))
fig = plt.gcf()
fig.set_size_inches(10,10)
ax.set_xticklabels(ax.get_xticklabels(),fontsize=12)

#Возраст
plt.subplot(235)
ax=sns.countplot(x="Age", data=db, facecolor=(0, 0, 0, 0),
                 linewidth=5,edgecolor=sns.color_palette("cividis", 3))
fig = plt.gcf()
fig.set_size_inches(10,10)
ax.set_xticklabels(ax.get_xticklabels(),fontsize=12)

#Регион
plt.subplot(233)
ax=sns.countplot(x="Region", data=db, facecolor=(0, 0, 0, 0),
                 linewidth=5,edgecolor=sns.color_palette("viridis", 3))
fig = plt.gcf()
fig.set_size_inches(10,10)
ax.set_xticklabels(ax.get_xticklabels(),fontsize=12,rotation=20)

#Семейное положение
plt.subplot(231)
ax=sns.countplot(x="Fstat", data=db, facecolor=(0, 0, 0, 0),
                 linewidth=5,edgecolor=sns.color_palette("hot", 3))
fig = plt.gcf()
fig.set_size_inches(10,10)
ax.set_xticklabels(ax.get_xticklabels(),fontsize=12)

#Количество детей
plt.subplot(232)
ax=sns.countplot(x="Children", data=db, facecolor=(0, 0, 0, 0),
                 linewidth=5,edgecolor=sns.color_palette("rocket", 3))
fig = plt.gcf()
fig.set_size_inches(10,10)
ax.set_xticklabels(ax.get_xticklabels(),fontsize=12)

#Уровень образования
plt.subplot(236)
ax=sns.countplot(x="Ed", data=db, facecolor=(0, 0, 0, 0),
                 linewidth=5,edgecolor=sns.color_palette("copper", 3))
fig = plt.gcf()
fig.set_size_inches(10,10)
ax.set_xticklabels(ax.get_xticklabels(),fontsize=12)

plt.figure(figsize = (15, 7))
plt.style.use('seaborn-white')

#Занятость
plt.subplot(234)
ax=sns.countplot(x="Emp", data=db, facecolor=(0, 0, 0, 0),
                 linewidth=5,edgecolor=sns.color_palette("magma", 3))
fig = plt.gcf()
fig.set_size_inches(10,10)
ax.set_xticklabels(ax.get_xticklabels(),fontsize=12)

#Стаж работы
plt.subplot(235)
ax=sns.countplot(x="Years", data=db, facecolor=(0, 0, 0, 0),
                 linewidth=5,edgecolor=sns.color_palette("cividis", 3))
fig = plt.gcf()
fig.set_size_inches(10,10)
ax.set_xticklabels(ax.get_xticklabels(),fontsize=12)

#Профессиональная группа лиц
plt.subplot(233)
ax=sns.countplot(x="Group", data=db, facecolor=(0, 0, 0, 0),
                 linewidth=5,edgecolor=sns.color_palette("viridis", 3))
fig = plt.gcf()
fig.set_size_inches(10,10)
ax.set_xticklabels(ax.get_xticklabels(),fontsize=12,rotation=20)

#Категория компании
plt.subplot(231)
ax=sns.countplot(x="Comp", data=db, facecolor=(0, 0, 0, 0),
                 linewidth=5,edgecolor=sns.color_palette("hot", 3))
fig = plt.gcf()
fig.set_size_inches(10,10)
ax.set_xticklabels(ax.get_xticklabels(),fontsize=12)

#Отрасль компании
plt.subplot(232)
ax=sns.countplot(x="Market", data=db, facecolor=(0, 0, 0, 0),
                 linewidth=5,edgecolor=sns.color_palette("rocket", 3))
fig = plt.gcf()
fig.set_size_inches(10,10)
ax.set_xticklabels(ax.get_xticklabels(),fontsize=12)
# Out:
# [Text(0, 0, 'Консалтинг'),
#  Text(1, 0, 'Телекоммуникации / Связь'),
#  Text(2, 0, 'Финансовый сектор (банки/ страховые и инвестиционные компании)'),
#  Text(3, 0, 'Энергетика'),
#  Text(4, 0, 'Информационные технологии'),
#  Text(5, 0, 'Государственный сектор'),
#  Text(6, 0, 'Не работал(-а)'),
#  Text(7, 0, 'Услуги'),
#  Text(8, 0, 'Медиа / Индустрия развлечений'),
#  Text(9, 0, 'Образовательный сектор'),
#  Text(10, 0, 'Промышленное оборудование (техника/ станки/ комплектующие)'),
#  Text(11, 0, 'Гостиничный бизнес / Туризм / Рестораны'),
#  Text(12, 0, 'Товары народного потребления (пищевые)'),
#  Text(13, 0, 'Фармацевтическая отрасль'),
#  Text(14, 0, 'Строительные материалы / Инструменты'),
#  Text(15, 0, 'Оптово-розничная торговля'),
#  Text(16, 0, 'Медицинское оборудование'),
#  Text(17, 0, 'Нефть и газ'),
#  Text(18, 0, 'Логистика и Закупки / Перевозки / Склад / ВЭД'),
#  Text(19, 0, 'Медицина'),
#  Text(20, 0, 'Спорт / Фитнес'),
# ...

# %% [markdown]
# ### Распределение оценки кандидатов уровня цифровизации рекрутмента

# %%
sns.set(rc={'figure.figsize':(12,8)})
f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw={"height_ratios": (.15, .85)})

sns.boxplot(db["Level"], ax=ax_box)
sns.distplot(db["Level"], ax=ax_hist)
 
# Remove x axis name for the boxplot
ax_box.set(xlabel='')
# Out:
# C:\Users\velom\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\velom\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0.5, 0, '')]

# %%
sns.set(rc={'figure.figsize':(12,8)})
f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw={"height_ratios": (.15, .85)})

sns.boxplot(db["Social1"], ax=ax_box)
sns.distplot(db["Social1"], ax=ax_hist)
 
# Remove x axis name for the boxplot
ax_box.set(xlabel='')
# Out:
# C:\Users\velom\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\velom\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0.5, 0, '')]

# %%
plt.style.use('seaborn-white')
f,ax=plt.subplots(1,2,figsize=(18,8))
db['Sex'].value_counts().plot.pie(explode=[0,0.05],autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('Sex')
sns.countplot(x = 'Sex',hue = "Social1",data = db)
ax[1].set_title('Распределение активности использования социальных сетей по полу')
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

# %%
# creat1ing initial dataframe
temp_db3 = pd.DataFrame(db3[['Region']])

# creating instance of labelencoder
labelencoder = LabelEncoder()

# Assigning numerical values and storing in another column
db['Region_id'] = labelencoder.fit_transform(temp_db3['Region'])

db.head(10)
# Out:
#        Sex    Age       Region                 Fstat   Children            Ed  \
# 0  Мужской  18–24  Москва и МО  Не женат/ не замужем  Нет детей   Бакалавриат
# 1  Женский  18–24  Москва и МО  Не женат/ не замужем  Нет детей  Магистратура
# 2  Женский  18–24  Москва и МО  Не женат/ не замужем  Нет детей  Магистратура
# 3  Женский  18–24  Москва и МО  Не женат/ не замужем  Нет детей   Бакалавриат
# 4  Женский  18–24  Москва и МО  Не женат/ не замужем  1 ребенок   Бакалавриат
# 5  Женский  18–24  Москва и МО  Не женат/ не замужем  1 ребенок  Магистратура
# 6  Женский  32–38  Москва и МО         Женат/замужем  Нет детей   Специалитет
# 7  Женский  32–38  Москва и МО  Не женат/ не замужем  3-е детей   Специалитет
# 8  Женский  25–31  Москва и МО         Женат/замужем  2-е детей   Специалитет
# 9  Женский  25–31  Москва и МО         Женат/замужем  Нет детей   Бакалавриат
#
#                                              Emp                    Years  \
# ...

# %%
g = sns.boxplot(y = "Social1",x = 'Region_id',data = db, whis=np.inf)
g = sns.swarmplot(y = "Social1",x = 'Region_id',data = db, size = 7,color = 'black')
sns.despine()
g.figure.set_size_inches(12,8)
plt.show()
# Out:
# C:\Users\velom\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1195: RuntimeWarning: invalid value encountered in double_scalars
#   loval = q1 - whis * stats['iqr']
# C:\Users\velom\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1196: RuntimeWarning: invalid value encountered in double_scalars
#   hival = q3 + whis * stats['iqr']
# C:\Users\velom\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 48.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\velom\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 30.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
# creat1ing initial dataframe
temp_db = pd.DataFrame(db[['Sex']])

# creating instance of labelencoder
labelencoder = LabelEncoder()

# Assigning numerical values and storing in another column
db['Sex_id'] = labelencoder.fit_transform(temp_db['Sex'])

db.head(10)
# Out:
#        Sex    Age       Region                 Fstat   Children            Ed  \
# 0  Мужской  18–24  Москва и МО  Не женат/ не замужем  Нет детей   Бакалавриат
# 1  Женский  18–24  Москва и МО  Не женат/ не замужем  Нет детей  Магистратура
# 2  Женский  18–24  Москва и МО  Не женат/ не замужем  Нет детей  Магистратура
# 3  Женский  18–24  Москва и МО  Не женат/ не замужем  Нет детей   Бакалавриат
# 4  Женский  18–24  Москва и МО  Не женат/ не замужем  1 ребенок   Бакалавриат
# 5  Женский  18–24  Москва и МО  Не женат/ не замужем  1 ребенок  Магистратура
# 6  Женский  32–38  Москва и МО         Женат/замужем  Нет детей   Специалитет
# 7  Женский  32–38  Москва и МО  Не женат/ не замужем  3-е детей   Специалитет
# 8  Женский  25–31  Москва и МО         Женат/замужем  2-е детей   Специалитет
# 9  Женский  25–31  Москва и МО         Женат/замужем  Нет детей   Бакалавриат
#
#                                              Emp                    Years  \
# ...

# %%
g = sns.boxplot(y = "Social1",x = 'Sex_id',data = db, whis=np.inf)
g = sns.swarmplot(y = "Social1",x = 'Sex_id',data = db, size = 7,color = 'black')
sns.despine()
g.figure.set_size_inches(12,8)
plt.show()
# Out:
# C:\Users\velom\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 9.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.countplot(x = db['VR'])
plt.show()

# %%
sns.countplot(x = db['Sex'])
plt.show()

# %%
grp_gen=pd.DataFrame(db.groupby('AdvDig')['AdvDig'].count())
grp_gen
# Out:
#                                                     AdvDig
# AdvDig
# Делают процесс подбора более увлекательным              20
# Делают процесс подбора более увлекательным/ Не ...       1
# Затрудняюсь ответить                                    34
# Не вижу в них никаких плюсов для соискателя             12
# Не вижу в них никаких плюсов для соискателя/ За...       1
# Положительно влияют на бренд работодателя                3
# Положительно влияют на бренд работодателя/ Дела...       4
# Положительно влияют на бренд работодателя/ Не в...       1
# Ускоряют процесс подбора                                56
# Ускоряют процесс подбора/ Делают процесс подбор...      15
# Ускоряют процесс подбора/ Затрудняюсь ответить           1
# Ускоряют процесс подбора/ Положительно влияют н...       9
# Ускоряют процесс подбора/ Положительно влияют н...      22
# Ускоряют процесс подбора/ Точно всё придёт робо...       1

# %%
grp_gen=pd.DataFrame(db.groupby('Sex')['Sex'].count())
grp_gen
# Out:
#          Sex
# Sex
# Женский  156
# Мужской   24

# %%
sns.countplot(x = db['Social3'])
plt.show()

# %%
grp_gen=pd.DataFrame(db.groupby('Social3')['Sex'].count())
grp_gen
# Out:
#               Sex
# Social3
# Нейтрально     84
# Отрицательно   19
# Положительно   77

# %%
db2=pd.read_csv("Плюсы цифровых инструментов.csv", sep=';')

# %%
grp_gen=pd.DataFrame(db2.groupby('Плюсы цифровых инструментов')['Плюсы цифровых инструментов'].count())
grp_gen
# Out:
#                                              Плюсы цифровых инструментов
# Плюсы цифровых инструментов
# Делают процесс подбора более увлекательным                            62
# Затрудняюсь ответить                                                  34
# Не вижу в них никаких плюсов для соискателя                           13
# Положительно влияют на бренд работодателя                             39
# Ускоряют процесс подбора                                             104

# %%
sns.countplot(x = db2['Плюсы цифровых инструментов'])
plt.show()

# %%
db3=pd.read_csv("Опрос_нов.csv", sep=';')

# %%
db3_copy=db3.copy()
db3_copy.head()
# Out:
#        Sex    Age       Region                 Fstat   Children            Ed  \
# 0  Мужской  18–24  Москва и МО  Не женат/ не замужем  Нет детей   Бакалавриат
# 1  Женский  18–24  Москва и МО  Не женат/ не замужем  Нет детей  Магистратура
# 2  Женский  18–24  Москва и МО  Не женат/ не замужем  Нет детей  Магистратура
# 3  Женский  18–24  Москва и МО  Не женат/ не замужем  Нет детей   Бакалавриат
# 4  Женский  18–24  Москва и МО  Не женат/ не замужем  1 ребенок   Бакалавриат
#
#                                              Emp                   Years  \
# 0          Работаю в компании (полная занятость)               До 1 года
# 1          Работаю в компании (полная занятость)  От 3-х лет до 5-ти лет
# 2          Работаю в компании (полная занятость)               До 1 года
# 3          Работаю в компании (полная занятость)  От 3-х лет до 5-ти лет
# 4  Совмещаю работу в офисе и собственные проекты  От 3-х лет до 5-ти лет
#
#                       Group  \
# ...

# %%
# creat1ing initial dataframe
temp_db3 = pd.DataFrame(db3[['Sex']])

# creating instance of labelencoder
labelencoder = LabelEncoder()

# Assigning numerical values and storing in another column
db3['Sex_id'] = labelencoder.fit_transform(temp_db3['Sex'])

db3.head(10)
# Out:
#          Sex    Age                                  Region  \
# 0    Мужской  18–24                             Москва и МО
# 1    Женский  18–24                             Москва и МО
# 2    Женский  18–24                             Москва и МО
# 3    Женский  18–24                             Москва и МО
# 4    Женский  18–24                             Москва и МО
# ..       ...    ...                                     ...
# 175  Мужской  25–31                             Москва и МО
# 176  Мужской  46–52                          Приволжский ФО
# 177  Мужской  32–38  Южный ФО / Северо-Кавказский ФО / Крым
# 178  Мужской  25–31                             Москва и МО
# 179  Мужской  18–24    Центральный ФО/ исключая Москву и МО
#
#                     Fstat   Children            Ed  \
# 0    Не женат/ не замужем  Нет детей   Бакалавриат
# 1    Не женат/ не замужем  Нет детей  Магистратура
# 2    Не женат/ не замужем  Нет детей  Магистратура
# ...

# %%
# creat1ing initial dataframe
temp_db3 = pd.DataFrame(db3[['Age']])

# creating instance of labelencoder
labelencoder = LabelEncoder()

# Assigning numerical values and storing in another column
db3['Age_id'] = labelencoder.fit_transform(temp_db3['Age'])

db3.head(180)
# Out:
#          Sex    Age                                  Region  \
# 0    Мужской  18–24                             Москва и МО
# 1    Женский  18–24                             Москва и МО
# 2    Женский  18–24                             Москва и МО
# 3    Женский  18–24                             Москва и МО
# 4    Женский  18–24                             Москва и МО
# ..       ...    ...                                     ...
# 175  Мужской  25–31                             Москва и МО
# 176  Мужской  46–52                          Приволжский ФО
# 177  Мужской  32–38  Южный ФО / Северо-Кавказский ФО / Крым
# 178  Мужской  25–31                             Москва и МО
# 179  Мужской  18–24    Центральный ФО/ исключая Москву и МО
#
#                     Fstat   Children            Ed  \
# 0    Не женат/ не замужем  Нет детей   Бакалавриат
# 1    Не женат/ не замужем  Нет детей  Магистратура
# 2    Не женат/ не замужем  Нет детей  Магистратура
# ...

# %%
# creat1ing initial dataframe
temp_db3 = pd.DataFrame(db3[['Region']])

# creating instance of labelencoder
labelencoder = LabelEncoder()

# Assigning numerical values and storing in another column
db3['Region_id'] = labelencoder.fit_transform(temp_db3['Region'])

db3.head(180)
# Out:
#          Sex    Age                                  Region  \
# 0    Мужской  18–24                             Москва и МО
# 1    Женский  18–24                             Москва и МО
# 2    Женский  18–24                             Москва и МО
# 3    Женский  18–24                             Москва и МО
# 4    Женский  18–24                             Москва и МО
# ..       ...    ...                                     ...
# 175  Мужской  25–31                             Москва и МО
# 176  Мужской  46–52                          Приволжский ФО
# 177  Мужской  32–38  Южный ФО / Северо-Кавказский ФО / Крым
# 178  Мужской  25–31                             Москва и МО
# 179  Мужской  18–24    Центральный ФО/ исключая Москву и МО
#
#                     Fstat   Children            Ed  \
# 0    Не женат/ не замужем  Нет детей   Бакалавриат
# 1    Не женат/ не замужем  Нет детей  Магистратура
# 2    Не женат/ не замужем  Нет детей  Магистратура
# ...

# %%
# creat1ing initial dataframe
temp_db3 = pd.DataFrame(db3[['Fstat']])

# creating instance of labelencoder
labelencoder = LabelEncoder()

# Assigning numerical values and storing in another column
db3['Fstat_id'] = labelencoder.fit_transform(temp_db3['Fstat'])

db3.head(10)
# Out:
#        Sex    Age       Region                 Fstat   Children            Ed  \
# 0  Мужской  18–24  Москва и МО  Не женат/ не замужем  Нет детей   Бакалавриат
# 1  Женский  18–24  Москва и МО  Не женат/ не замужем  Нет детей  Магистратура
# 2  Женский  18–24  Москва и МО  Не женат/ не замужем  Нет детей  Магистратура
# 3  Женский  18–24  Москва и МО  Не женат/ не замужем  Нет детей   Бакалавриат
# 4  Женский  18–24  Москва и МО  Не женат/ не замужем  1 ребенок   Бакалавриат
# 5  Женский  18–24  Москва и МО  Не женат/ не замужем  1 ребенок  Магистратура
# 6  Женский  32–38  Москва и МО         Женат/замужем  Нет детей   Специалитет
# 7  Женский  32–38  Москва и МО  Не женат/ не замужем  3-е детей   Специалитет
# 8  Женский  25–31  Москва и МО         Женат/замужем  2-е детей   Специалитет
# 9  Женский  25–31  Москва и МО         Женат/замужем  Нет детей   Бакалавриат
#
#                                              Emp                    Years  \
# ...

# %%
# creat1ing initial dataframe
temp_db3 = pd.DataFrame(db3[['Children']])

# creating instance of labelencoder
labelencoder = LabelEncoder()

# Assigning numerical values and storing in another column
db3['Children_id'] = labelencoder.fit_transform(temp_db3['Children'])

db3.head(5)
# Out:
#        Sex    Age       Region                 Fstat   Children            Ed  \
# 0  Мужской  18–24  Москва и МО  Не женат/ не замужем  Нет детей   Бакалавриат
# 1  Женский  18–24  Москва и МО  Не женат/ не замужем  Нет детей  Магистратура
# 2  Женский  18–24  Москва и МО  Не женат/ не замужем  Нет детей  Магистратура
# 3  Женский  18–24  Москва и МО  Не женат/ не замужем  Нет детей   Бакалавриат
# 4  Женский  18–24  Москва и МО  Не женат/ не замужем  1 ребенок   Бакалавриат
#
#                                              Emp                   Years  \
# 0          Работаю в компании (полная занятость)               До 1 года
# 1          Работаю в компании (полная занятость)  От 3-х лет до 5-ти лет
# 2          Работаю в компании (полная занятость)               До 1 года
# 3          Работаю в компании (полная занятость)  От 3-х лет до 5-ти лет
# 4  Совмещаю работу в офисе и собственные проекты  От 3-х лет до 5-ти лет
#
#                       Group  \
# ...

# %%
# creat1ing initial dataframe
temp_db3 = pd.DataFrame(db3[['Ed']])

# creating instance of labelencoder
labelencoder = LabelEncoder()

# Assigning numerical values and storing in another column
db3['Ed_id'] = labelencoder.fit_transform(temp_db3['Ed'])

db3.head(5)
# Out:
#        Sex    Age       Region                 Fstat   Children            Ed  \
# 0  Мужской  18–24  Москва и МО  Не женат/ не замужем  Нет детей   Бакалавриат
# 1  Женский  18–24  Москва и МО  Не женат/ не замужем  Нет детей  Магистратура
# 2  Женский  18–24  Москва и МО  Не женат/ не замужем  Нет детей  Магистратура
# 3  Женский  18–24  Москва и МО  Не женат/ не замужем  Нет детей   Бакалавриат
# 4  Женский  18–24  Москва и МО  Не женат/ не замужем  1 ребенок   Бакалавриат
#
#                                              Emp                   Years  \
# 0          Работаю в компании (полная занятость)               До 1 года
# 1          Работаю в компании (полная занятость)  От 3-х лет до 5-ти лет
# 2          Работаю в компании (полная занятость)               До 1 года
# 3          Работаю в компании (полная занятость)  От 3-х лет до 5-ти лет
# 4  Совмещаю работу в офисе и собственные проекты  От 3-х лет до 5-ти лет
#
#                       Group  \
# ...

# %%
# creat1ing initial dataframe
temp_db3 = pd.DataFrame(db3[['Emp']])

# creating instance of labelencoder
labelencoder = LabelEncoder()

# Assigning numerical values and storing in another column
db3['Emp_id'] = labelencoder.fit_transform(temp_db3['Emp'])

db3.head(5)
# Out:
#        Sex    Age       Region                 Fstat   Children            Ed  \
# 0  Мужской  18–24  Москва и МО  Не женат/ не замужем  Нет детей   Бакалавриат
# 1  Женский  18–24  Москва и МО  Не женат/ не замужем  Нет детей  Магистратура
# 2  Женский  18–24  Москва и МО  Не женат/ не замужем  Нет детей  Магистратура
# 3  Женский  18–24  Москва и МО  Не женат/ не замужем  Нет детей   Бакалавриат
# 4  Женский  18–24  Москва и МО  Не женат/ не замужем  1 ребенок   Бакалавриат
#
#                                              Emp                   Years  \
# 0          Работаю в компании (полная занятость)               До 1 года
# 1          Работаю в компании (полная занятость)  От 3-х лет до 5-ти лет
# 2          Работаю в компании (полная занятость)               До 1 года
# 3          Работаю в компании (полная занятость)  От 3-х лет до 5-ти лет
# 4  Совмещаю работу в офисе и собственные проекты  От 3-х лет до 5-ти лет
#
#                       Group  \
# ...

# %%
# creat1ing initial dataframe
temp_db3 = pd.DataFrame(db3[['Years']])

# creating instance of labelencoder
labelencoder = LabelEncoder()

# Assigning numerical values and storing in another column
db3['Years_id'] = labelencoder.fit_transform(temp_db3['Years'])

db3.head(5)
# Out:
#        Sex    Age       Region                 Fstat   Children            Ed  \
# 0  Мужской  18–24  Москва и МО  Не женат/ не замужем  Нет детей   Бакалавриат
# 1  Женский  18–24  Москва и МО  Не женат/ не замужем  Нет детей  Магистратура
# 2  Женский  18–24  Москва и МО  Не женат/ не замужем  Нет детей  Магистратура
# 3  Женский  18–24  Москва и МО  Не женат/ не замужем  Нет детей   Бакалавриат
# 4  Женский  18–24  Москва и МО  Не женат/ не замужем  1 ребенок   Бакалавриат
#
#                                              Emp                   Years  \
# 0          Работаю в компании (полная занятость)               До 1 года
# 1          Работаю в компании (полная занятость)  От 3-х лет до 5-ти лет
# 2          Работаю в компании (полная занятость)               До 1 года
# 3          Работаю в компании (полная занятость)  От 3-х лет до 5-ти лет
# 4  Совмещаю работу в офисе и собственные проекты  От 3-х лет до 5-ти лет
#
#                       Group  \
# ...

# %%
# creat1ing initial dataframe
temp_db3 = pd.DataFrame(db3[['Group']])

# creating instance of labelencoder
labelencoder = LabelEncoder()

# Assigning numerical values and storing in another column
db3['Group_id'] = labelencoder.fit_transform(temp_db3['Group'])

db3.head(5)
# Out:
#        Sex    Age       Region                 Fstat   Children            Ed  \
# 0  Мужской  18–24  Москва и МО  Не женат/ не замужем  Нет детей   Бакалавриат
# 1  Женский  18–24  Москва и МО  Не женат/ не замужем  Нет детей  Магистратура
# 2  Женский  18–24  Москва и МО  Не женат/ не замужем  Нет детей  Магистратура
# 3  Женский  18–24  Москва и МО  Не женат/ не замужем  Нет детей   Бакалавриат
# 4  Женский  18–24  Москва и МО  Не женат/ не замужем  1 ребенок   Бакалавриат
#
#                                              Emp                   Years  \
# 0          Работаю в компании (полная занятость)               До 1 года
# 1          Работаю в компании (полная занятость)  От 3-х лет до 5-ти лет
# 2          Работаю в компании (полная занятость)               До 1 года
# 3          Работаю в компании (полная занятость)  От 3-х лет до 5-ти лет
# 4  Совмещаю работу в офисе и собственные проекты  От 3-х лет до 5-ти лет
#
#                       Group  \
# ...

# %%
# creat1ing initial dataframe
temp_db3 = pd.DataFrame(db3[['Comp']])

# creating instance of labelencoder
labelencoder = LabelEncoder()

# Assigning numerical values and storing in another column
db3['Comp_id'] = labelencoder.fit_transform(temp_db3['Comp'])

db3.head(5)
# Out:
#        Sex    Age       Region                 Fstat   Children            Ed  \
# 0  Мужской  18–24  Москва и МО  Не женат/ не замужем  Нет детей   Бакалавриат
# 1  Женский  18–24  Москва и МО  Не женат/ не замужем  Нет детей  Магистратура
# 2  Женский  18–24  Москва и МО  Не женат/ не замужем  Нет детей  Магистратура
# 3  Женский  18–24  Москва и МО  Не женат/ не замужем  Нет детей   Бакалавриат
# 4  Женский  18–24  Москва и МО  Не женат/ не замужем  1 ребенок   Бакалавриат
#
#                                              Emp                   Years  \
# 0          Работаю в компании (полная занятость)               До 1 года
# 1          Работаю в компании (полная занятость)  От 3-х лет до 5-ти лет
# 2          Работаю в компании (полная занятость)               До 1 года
# 3          Работаю в компании (полная занятость)  От 3-х лет до 5-ти лет
# 4  Совмещаю работу в офисе и собственные проекты  От 3-х лет до 5-ти лет
#
#                       Group  \
# ...

# %%
# creat1ing initial dataframe
temp_db3 = pd.DataFrame(db3[['Market']])

# creating instance of labelencoder
labelencoder = LabelEncoder()

# Assigning numerical values and storing in another column
db3['Market_id'] = labelencoder.fit_transform(temp_db3['Market'])

db3.head(5)
# Out:
#        Sex    Age       Region                 Fstat   Children            Ed  \
# 0  Мужской  18–24  Москва и МО  Не женат/ не замужем  Нет детей   Бакалавриат
# 1  Женский  18–24  Москва и МО  Не женат/ не замужем  Нет детей  Магистратура
# 2  Женский  18–24  Москва и МО  Не женат/ не замужем  Нет детей  Магистратура
# 3  Женский  18–24  Москва и МО  Не женат/ не замужем  Нет детей   Бакалавриат
# 4  Женский  18–24  Москва и МО  Не женат/ не замужем  1 ребенок   Бакалавриат
#
#                                              Emp                   Years  \
# 0          Работаю в компании (полная занятость)               До 1 года
# 1          Работаю в компании (полная занятость)  От 3-х лет до 5-ти лет
# 2          Работаю в компании (полная занятость)               До 1 года
# 3          Работаю в компании (полная занятость)  От 3-х лет до 5-ти лет
# 4  Совмещаю работу в офисе и собственные проекты  От 3-х лет до 5-ти лет
#
#                       Group  \
# ...

# %%
# creat1ing initial dataframe
temp_db3 = pd.DataFrame(db3[['Sphere']])

# creating instance of labelencoder
labelencoder = LabelEncoder()

# Assigning numerical values and storing in another column
db3['Sphere_id'] = labelencoder.fit_transform(temp_db3['Sphere'])

db3.head(5)
# Out:
#        Sex    Age       Region                 Fstat   Children            Ed  \
# 0  Мужской  18–24  Москва и МО  Не женат/ не замужем  Нет детей   Бакалавриат
# 1  Женский  18–24  Москва и МО  Не женат/ не замужем  Нет детей  Магистратура
# 2  Женский  18–24  Москва и МО  Не женат/ не замужем  Нет детей  Магистратура
# 3  Женский  18–24  Москва и МО  Не женат/ не замужем  Нет детей   Бакалавриат
# 4  Женский  18–24  Москва и МО  Не женат/ не замужем  1 ребенок   Бакалавриат
#
#                                              Emp                   Years  \
# 0          Работаю в компании (полная занятость)               До 1 года
# 1          Работаю в компании (полная занятость)  От 3-х лет до 5-ти лет
# 2          Работаю в компании (полная занятость)               До 1 года
# 3          Работаю в компании (полная занятость)  От 3-х лет до 5-ти лет
# 4  Совмещаю работу в офисе и собственные проекты  От 3-х лет до 5-ти лет
#
#                       Group  \
# ...

# %%
# creat1ing initial dataframe
temp_db3 = pd.DataFrame(db3[['Sphere']])

# creating instance of labelencoder
labelencoder = LabelEncoder()

# Assigning numerical values and storing in another column
db3['Sphere_id'] = labelencoder.fit_transform(temp_db3['Sphere'])

db3.head(5)
# Out:
#        Sex    Age       Region                 Fstat   Children            Ed  \
# 0  Мужской  18–24  Москва и МО  Не женат/ не замужем  Нет детей   Бакалавриат
# 1  Женский  18–24  Москва и МО  Не женат/ не замужем  Нет детей  Магистратура
# 2  Женский  18–24  Москва и МО  Не женат/ не замужем  Нет детей  Магистратура
# 3  Женский  18–24  Москва и МО  Не женат/ не замужем  Нет детей   Бакалавриат
# 4  Женский  18–24  Москва и МО  Не женат/ не замужем  1 ребенок   Бакалавриат
#
#                                              Emp                   Years  \
# 0          Работаю в компании (полная занятость)               До 1 года
# 1          Работаю в компании (полная занятость)  От 3-х лет до 5-ти лет
# 2          Работаю в компании (полная занятость)               До 1 года
# 3          Работаю в компании (полная занятость)  От 3-х лет до 5-ти лет
# 4  Совмещаю работу в офисе и собственные проекты  От 3-х лет до 5-ти лет
#
#                       Group  \
# ...

# %%
sns.heatmap(db3.corr(),annot=True,fmt='.1g',cmap='Greys')
# Out:
# <AxesSubplot:>

# %%
# creat1ing initial dataframe
temp_db3 = pd.DataFrame(db3[['Social3']])

# creating instance of labelencoder
labelencoder = LabelEncoder()

# Assigning numerical values and storing in another column
db3['Social3_id'] = labelencoder.fit_transform(temp_db3['Social3'])

db3.head(5)
# Out:
#        Sex    Age       Region                 Fstat   Children            Ed  \
# 0  Мужской  18–24  Москва и МО  Не женат/ не замужем  Нет детей   Бакалавриат
# 1  Женский  18–24  Москва и МО  Не женат/ не замужем  Нет детей  Магистратура
# 2  Женский  18–24  Москва и МО  Не женат/ не замужем  Нет детей  Магистратура
# 3  Женский  18–24  Москва и МО  Не женат/ не замужем  Нет детей   Бакалавриат
# 4  Женский  18–24  Москва и МО  Не женат/ не замужем  1 ребенок   Бакалавриат
#
#                                              Emp                   Years  \
# 0          Работаю в компании (полная занятость)               До 1 года
# 1          Работаю в компании (полная занятость)  От 3-х лет до 5-ти лет
# 2          Работаю в компании (полная занятость)               До 1 года
# 3          Работаю в компании (полная занятость)  От 3-х лет до 5-ти лет
# 4  Совмещаю работу в офисе и собственные проекты  От 3-х лет до 5-ти лет
#
#                       Group  \
# ...

# %%
# creat1ing initial dataframe
temp_db3 = pd.DataFrame(db3[['AI']])

# creating instance of labelencoder
labelencoder = LabelEncoder()

# Assigning numerical values and storing in another column
db3['AI_id'] = labelencoder.fit_transform(temp_db3['AI'])

db3.head(5)
# Out:
#        Sex    Age       Region                 Fstat   Children            Ed  \
# 0  Мужской  18–24  Москва и МО  Не женат/ не замужем  Нет детей   Бакалавриат
# 1  Женский  18–24  Москва и МО  Не женат/ не замужем  Нет детей  Магистратура
# 2  Женский  18–24  Москва и МО  Не женат/ не замужем  Нет детей  Магистратура
# 3  Женский  18–24  Москва и МО  Не женат/ не замужем  Нет детей   Бакалавриат
# 4  Женский  18–24  Москва и МО  Не женат/ не замужем  1 ребенок   Бакалавриат
#
#                                              Emp                   Years  \
# 0          Работаю в компании (полная занятость)               До 1 года
# 1          Работаю в компании (полная занятость)  От 3-х лет до 5-ти лет
# 2          Работаю в компании (полная занятость)               До 1 года
# 3          Работаю в компании (полная занятость)  От 3-х лет до 5-ти лет
# 4  Совмещаю работу в офисе и собственные проекты  От 3-х лет до 5-ти лет
#
#                       Group  \
# ...

# %%
# creat1ing initial dataframe
temp_db3 = pd.DataFrame(db3[['VR']])

# creating instance of labelencoder
labelencoder = LabelEncoder()

# Assigning numerical values and storing in another column
db3['VR_id'] = labelencoder.fit_transform(temp_db3['VR'])

db3.head(5)
# Out:
#        Sex    Age       Region                 Fstat   Children            Ed  \
# 0  Мужской  18–24  Москва и МО  Не женат/ не замужем  Нет детей   Бакалавриат
# 1  Женский  18–24  Москва и МО  Не женат/ не замужем  Нет детей  Магистратура
# 2  Женский  18–24  Москва и МО  Не женат/ не замужем  Нет детей  Магистратура
# 3  Женский  18–24  Москва и МО  Не женат/ не замужем  Нет детей   Бакалавриат
# 4  Женский  18–24  Москва и МО  Не женат/ не замужем  1 ребенок   Бакалавриат
#
#                                              Emp                   Years  \
# 0          Работаю в компании (полная занятость)               До 1 года
# 1          Работаю в компании (полная занятость)  От 3-х лет до 5-ти лет
# 2          Работаю в компании (полная занятость)               До 1 года
# 3          Работаю в компании (полная занятость)  От 3-х лет до 5-ти лет
# 4  Совмещаю работу в офисе и собственные проекты  От 3-х лет до 5-ти лет
#
#                       Group  \
# ...

# %%
sns.heatmap(db3.corr(),annot=True,fmt='.1g',cmap='Greys')
# Out:
# <AxesSubplot:>

# %%
cols = ['Social3', 'AI_id', 'VR_id', 'Level', 'Social1']

sns.pairplot(db3[cols], height=2.5)

# %%
cols = ['Ed_id', 'Emp_id', 'Years_id', 'Group_id', 'Comp_id', 'Market_id', 'Sphere_id', 'Social3_id', 'AI_id', 'VR_id']

sns.pairplot(db3[cols], height=2.5)

# %%
X = db3[['Children_id']].values
y = db3['Social3_id'].values

# %%
from sklearn.linear_model import LinearRegression
slr = LinearRegression()
slr.fit(X, y)
y_pred = slr.predict(X)
print('Slope: {:.2f}'.format(slr.coef_[0]))
print('Intercept: {:.2f}'.format(slr.intercept_))
# Out:
# Slope: 0.08
# Intercept: 0.75

# %%
plt.scatter(X, y)
plt.plot(X, slr.predict(X), color='red', linewidth=2)

# %%
X = db3[['Group_id']].values
y = db3['Level'].values

# %%
from sklearn.linear_model import LinearRegression
slr = LinearRegression()
slr.fit(X, y)
y_pred = slr.predict(X)
print('Slope: {:.2f}'.format(slr.coef_[0]))
print('Intercept: {:.2f}'.format(slr.intercept_))
# Out:
# Slope: -0.04
# Intercept: 2.78

# %%
plt.scatter(X, y)
plt.plot(X, slr.predict(X), color='red', linewidth=2)

# %%
dummy_Social3=pd.get_dummies(db3['Social3'], prefix='dummy')
dummy_AI=pd.get_dummies(db3['AI'], prefix='dummy')
dummy_VR=pd.get_dummies(db3['VR'], prefix='dummy')
dummy_Sex=pd.get_dummies(db3['Sex'], prefix='dummy')
dummy_Age=pd.get_dummies(db3['Age'], prefix='dummy')
dummy_Region=pd.get_dummies(db3['Region'], prefix='dummy')
db3_coded = pd.concat([db3, dummy_Social3,dummy_AI,dummy_VR, dummy_Sex, dummy_Age, dummy_Region],axis=1)
db3_coded.drop(['Social3','AI','VR','Sex','Age', 'Region'],axis=1, inplace=True)
db3_coded.head()
# Out:
#                   Fstat   Children            Ed  \
# 0  Не женат/ не замужем  Нет детей   Бакалавриат
# 1  Не женат/ не замужем  Нет детей  Магистратура
# 2  Не женат/ не замужем  Нет детей  Магистратура
# 3  Не женат/ не замужем  Нет детей   Бакалавриат
# 4  Не женат/ не замужем  1 ребенок   Бакалавриат
#
#                                              Emp                   Years  \
# 0          Работаю в компании (полная занятость)               До 1 года
# 1          Работаю в компании (полная занятость)  От 3-х лет до 5-ти лет
# 2          Работаю в компании (полная занятость)               До 1 года
# 3          Работаю в компании (полная занятость)  От 3-х лет до 5-ти лет
# 4  Совмещаю работу в офисе и собственные проекты  От 3-х лет до 5-ти лет
#
#                       Group  \
# 0                Специалист
# 1                Специалист
# 2  Представитель HR-функции
# 3          Стажер/ассистент
# 4  Представитель HR-функции
#
# ...

# %%
X = db3_coded[['dummy_Москва и МО']].values
y = db3_coded['Social1'].values

# %%
from sklearn.linear_model import LinearRegression
slr = LinearRegression()
slr.fit(X, y)
y_pred = slr.predict(X)
print('Slope: {:.2f}'.format(slr.coef_[0]))
print('Intercept: {:.2f}'.format(slr.intercept_))
# Out:
# Slope: 0.22
# Intercept: 2.53

# %%
plt.scatter(X, y)
plt.plot(X, slr.predict(X), color='red', linewidth=2)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y,train_size=0.8,random_state=1)
print("Input Training:",X_train.shape)
print("Input Test:",X_test.shape)
print("Output Training:",y_train.shape)
print("Output Test:",y_test.shape)
# Out:
# Input Training: (144, 1)
# Input Test: (36, 1)
# Output Training: (144,)
# Output Test: (36,)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
logreg = LogisticRegression()
logreg.fit(X_train, y_train)
y_pred = logreg.predict(X_test)
print('Accuracy of logistic regression classifier on test set: {:.2f}'.format(logreg.score(X_test, y_test)))
# Out:
# Accuracy of logistic regression classifier on test set: 0.44

# %%
sns.pairplot(db3,vars=['Social1','Social3_id','AI_id'],hue="Age_id")
